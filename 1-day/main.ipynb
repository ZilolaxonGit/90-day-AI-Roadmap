# %%
full_diagram = """

AI
│
├── Machine Learning
│   ├── Supervised
│   ├── Unsupervised
│   └── Reinforcement
│
├── Deep Learning
│   ├── Neural Networks
│   ├── CNNs (Vision)
│   ├── RNNs/LSTMs (Old NLP)
│   └── Transformers (Modern NLP)
│
├── Natural Language Processing (NLP)
│   ├── Tokenization
│   ├── Sentiment Analysis
│   ├── Translation
│   ├── Chatbots
│   └── LLMs
│
├── Computer Vision
│   ├── Classification
│   ├── Object detection
│   ├── Segmentation
│   └── Pose estimation
│
├── Generative AI
│   ├── Text
│   ├── Images
│   ├── Audio
│   └── Video
│
└── MLOps (Deployment)


"""

print(full_diagram)
# Out:
# AI
# │
# ├── Machine Learning
# │   ├── Supervised
# │   ├── Unsupervised
# │   └── Reinforcement
# │
# ├── Deep Learning
# │   ├── Neural Networks
# │   ├── CNNs (Vision)
# │   ├── RNNs/LSTMs (Old NLP)
# │   └── Transformers (Modern NLP)
# │
# ├── Natural Language Processing (NLP)
# │   ├── Tokenization
# │   ├── Sentiment Analysis
# │   ├── Translation
# │   ├── Chatbots
# │   └── LLMs
# │
# ├── Computer Vision
# │   ├── Classification
# │   ├── Object detection
# │   ├── Segmentation
# │   └── Pose estimation
# │
# ├── Generative AI
# │   ├── Text
# │   ├── Images
# │   ├── Audio
# │   └── Video
# │
# └── MLOps (Deployment)
